# %% [markdown]
# Import Require Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load the Iris dataset

# %%
dfData = pd.read_csv("content/iris.data")
names = ["sepal_length","sepal_width","petal_length","petal_width","class"]
dfData.to_csv("Iris.csv",header=names,index=False)
df =pd.read_csv("Iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
df.shape
# Out:
# (149, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
df.info()  # to get info about dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  149 non-null    float64
#  1   sepal_width   149 non-null    float64
#  2   petal_length  149 non-null    float64
#  3   petal_width   149 non-null    float64
#  4   class         149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
df.isna().sum()  # to get length of eacj column
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.051007      3.774497     1.205369
# std        0.828594     0.433499      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.corr()
# Out:
# C:\Users\yoges\AppData\Local\Temp\ipykernel_16156\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.103784      0.871283     0.816971
# sepal_width      -0.103784     1.000000     -0.415218    -0.350733
# petal_length      0.871283    -0.415218      1.000000     0.962314
# petal_width       0.816971    -0.350733      0.962314     1.000000

# %% [markdown]
# Data Visualization

# %% [markdown]
# 1) HeadMap

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,fmt='.3f')
# Out:
# C:\Users\yoges\AppData\Local\Temp\ipykernel_16156\2129972787.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,linewidths=0.5,fmt='.3f')
# <Axes: >

# %% [markdown]
# 2) Scatter plot

# %%
f,ax = plt.subplots(figsize=(20,10))
#df =pd.read_csv("Iris.csv")
sns.scatterplot('sepal_length','sepal_width',hue='class',data = df)
plt.title("Sepal length VS Sepal Width\n",fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 f,ax = plt.subplots(figsize=(20,10))
#       2 #df =pd.read_csv("Iris.csv")
# ----> 3 sns.scatterplot('sepal_length','sepal_width',hue='class',data = df)
#       4 plt.title("Sepal length VS Sepal Width\n",fontsize=20)
#
# TypeError: scatterplot() got multiple values for argument 'data'

# %% [markdown]
# 3) Barplot

# %%
f,ax = plt.subplots(figsize=(20,10))
ax = sns.barplot('class','sepal length',data = df)
plt.title("Different class VS Sepal length \n", fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 f,ax = plt.subplots(figsize=(20,10))
# ----> 2 ax = sns.barplot('class','sepal length',data = df)
#       3 plt.title("Different class VS Sepal length \n", fontsize=20)
#
# TypeError: barplot() got multiple values for argument 'data'

# %%
f,ax = plt.subplots(figsize=(20,10))
ax = sns.barplot('class','sepal width',data=df)
plt.title("Different class VS sepal width\n",fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 f,ax = plt.subplots(figsize=(20,10))
# ----> 2 ax = sns.barplot('class','sepal width',data=df)
#       3 plt.title("Different class VS sepal width\n",fontsize=20)
#
# TypeError: barplot() got multiple values for argument 'data'

# %%
f,ax = plt.subplots(figsize=(20,10))
ax = sns.barplot('class','petal width',data=df)
plt.title("Different class VS sepal width\n",fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 f,ax = plt.subplots(figsize=(20,10))
# ----> 2 ax = sns.barplot('class','petal width',data=df)
#       3 plt.title("Different class VS sepal width\n",fontsize=20)
#
# TypeError: barplot() got multiple values for argument 'data'

# %% [markdown]
# 4) Boxplot

# %%
plt.figure(figsize=(20,10))
Iris_versicolor = df[df['class']=='Iris-versicolor']
sns.boxplot(data=Iris_versicolor)
plt.title("Iris_Versicolor\n",fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,10))
Iris_setosa = df[df['class'] == 'Iris-setosa']
sns.boxplot(data = Iris_setosa)
plt.title("Iris_setosa\n",fontsize=20)
plt.show()

# %%
plt.figure(figsize=(20,10))
Iris_virginica = df[df['class']=='Iris-virginica']
sns.boxplot(data = Iris_virginica)
plt.title("Iris_virginica\n",fontsize=20)
plt.show()

# %% [markdown]
# 5) Pairplot

# %%
sns.pairplot(df,hue='class')

# %% [markdown]
# 6) Pieplot

# %%
fig = plt.figure()
x = fig.add_axes([0,0,1,1])
x.axis('equal')
l = ['Iris-versicolor','Iris-setosa','Iris-virginica']
s = [30,30,30]
x.pie(s, labels = l,autopct='%1.2f%%')
plt.show()

# %% [markdown]
# Build the Models

# %%
X_train = df.drop('class',axis=1)
Y_train = df['class']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

#splitting data in training set(80%) and test set(20%)
x_train , x_test , y_train, y_test = train_test_split(X_train, Y_train ,test_size=0.2)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
Ir = LogisticRegression() #Create the abject of model
Ir = Ir.fit(x_train,y_train)

act = accuracy_score(y_train, Ir.predict(x_train))
print("Training Accuracy is : ",(act*100))

act = accuracy_score(y_test, Ir.predict(x_test))
print("Test Accuracy is : ",(act*100))
# Out:
# Training Accuracy is :  97.47899159663865
# Test Accuracy is :  96.66666666666667
# c:\Users\yoges\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Decision Tree Classification

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt = dt.fit(x_train , y_train)

act = accuracy_score(y_train , dt.predict(x_train))
print("Training Accuracy : ",(act*100))

act = accuracy_score(y_test , dt.predict(x_test))
print("Test Accuracy : ",(act*100))
# Out:
# Training Accuracy :  100.0
# Test Accuracy :  96.66666666666667

# %% [markdown]
# KNN Classification

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn = knn.fit(x_train , y_train)

act = accuracy_score(y_train , knn.predict(x_train))
print("Training accuracy is : ",(act*100))

act = accuracy_score(y_test , knn.predict(x_test))
print("Test Accuracy is : ",(act*100))
# Out:
# Training accuracy is :  97.47899159663865
# Test Accuracy is :  96.66666666666667

# %% [markdown]
# Support Vector Machine

# %%
from sklearn.svm import SVC
svm = SVC()
svm = svm.fit(x_train , y_train)

act = accuracy_score(y_train, svm.predict(x_train))
print("Training accuracy is : ",(act*100)) 

act = accuracy_score(y_test , svm.predict(x_test))
print("Test accuracy is : ",(act*100))
# Out:
# Training accuracy is :  97.47899159663865
# Test accuracy is :  96.66666666666667

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier() 
rf = rf.fit(x_train , y_train) 

act = accuracy_score( y_train , rf.predict(x_train))
print("Training accuracy is : ",(act*100)) 

act = accuracy_score(y_test , rf.predict(x_test)) 
print("Test accuracy is : ",(act*100))
# Out:
# Training accuracy is :  100.0
# Test accuracy is :  96.66666666666667

# %% [markdown]
# CONCLUSION:
#     The accuracy for Classification of Iris Flower based on following classifier is
# Logistic Regression      = 96%
# SVC                      = 96%
# KNN                      = 96%
# Random Forest classifier = 96%
# Decision Tree Classifier = 96%
